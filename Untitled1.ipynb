# %% [markdown]
# <a href="https://colab.research.google.com/github/uchoasilvagomeskaicjose-commits/atividades-alp-20261inf/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
soma = 0
quantidade = 0
maior = 0

while True:
    numero = int(input("Digite um número inteiro positivo (negativo para encerrar): "))

    if numero < 0:
        break


    soma += numero
    quantidade += 1

    if quantidade == 1 or numero > maior:
        maior = numero

if quantidade > 0:
    media = soma / quantidade
    print(f"Soma: {soma}")
    print(f"Média: {media:.2f}")
    print(f"Maior número: {maior}")
else:
    print("Nenhum número positivo foi informado.")
# Out:
# Digite um número inteiro positivo (negativo para encerrar): 2
# Digite um número inteiro positivo (negativo para encerrar): 5
# Digite um número inteiro positivo (negativo para encerrar): 7
# Digite um número inteiro positivo (negativo para encerrar): 6
# Digite um número inteiro positivo (negativo para encerrar): 13
# Digite um número inteiro positivo (negativo para encerrar): 8
# Digite um número inteiro positivo (negativo para encerrar): 4
# Digite um número inteiro positivo (negativo para encerrar): 10
# Digite um número inteiro positivo (negativo para encerrar): 9
# Digite um número inteiro positivo (negativo para encerrar): -8
# Soma: 64
# Média: 7.11
# Maior número: 13
